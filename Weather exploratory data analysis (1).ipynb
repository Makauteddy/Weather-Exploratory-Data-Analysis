# %%
#Import python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the dataset
data=pd.read_csv("C:\\Users\\ADMIN\\Desktop\\1. Weather Data.csv")

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
#  # 1. Data overview and Cleaning

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# # 1.1 The key characteristics of the dataset:

# %% [markdown]
# 1. It has 8784 rows and 8 columns
# 2. It has float64(4), int64(2), object(2) as features

# %% [markdown]
# # 1.2 missing values or null values

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# The dataset has no missing values

# %% [markdown]
# # 1.3 Check for duplicate values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The dataset has no duplicated values

# %% [markdown]
#  # 2. Statistical summary

# %% [markdown]
# ### 2.1 Statistical summary of the dataset

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ### 2.2  any significant outliers

# %% [markdown]
# The maximum recorded wind speed of 83.00 km/h is a significant outlier. It is considerably higher than the typical range of wind speeds, which is between 0.00 km/h and 36.50 km/h.
#
# Both the minimum value of 0.20 km and the maximum value of 48.30 km are notable outliers. The visibility typically ranges between 22.75 km and 26.35 km, making these values particularly unusual. The low visibility might indicate extreme weather conditions like fog, while the high visibility could correspond to exceptionally clear condition.
#
# The dataset shows pressure values as low as 97.52 kPa and as high as 103.65 kPa, both of which are significant outliers

# %% [markdown]
# # 3. Data visualization

# %% [markdown]
# ### 3.1  Visualizations to show the distribution of key weather patterns(temperature, humidity and windspeed)

# %%
plt.hist(data['Temp_C'])
plt.xlabel('Temperature')
plt.ylabel('Frequency');
plt.title('frequency distribution foe temparature');

# %%
plt.hist(data['Rel Hum_%'])
plt.xlabel('Humidity')
plt.ylabel('Frequency');
plt.title('frequency distribution for humidity');

# %%
plt.hist(data['Wind Speed_km/h'])
plt.xlabel('wind speed in km\h')
plt.ylabel('Frequency');
plt.title('frequency distribution for windspeed');

# %% [markdown]
# ### 3.2  Timeseries graph to visualize trends over time

# %%
plt.figure(figsize=(15,10))

# Plot for Temperature
plt.plot(data['Date/Time'], data['Temp_C'], color='gold', label='Temperature (°C)')

# Plot for Humidity
plt.plot(data['Date/Time'], data['Rel Hum_%'], color='black', label='Relative Humidity (%)')

# Title and labels
plt.title('Temperature and Humidity over Time')
plt.xlabel('Date')
plt.ylabel('Values')

# Show legend
plt.legend()

# Adjust layout and display plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 Correlation matrices and heatmaps to identify relationships between different weather patterns

# %% [markdown]
# #### 3.3.1 Correlation matrices

# %%
# Select only numerical columns
numerical_data = data.select_dtypes(include=['float64', 'int64'])

# Calculate the Spearman correlation matrix and round to 2 decimal places
correlation_matrix = numerical_data.corr(method='pearson').round(2)

# Style the correlation matrix with a uniform green background color
styled_matrix = correlation_matrix.style.background_gradient(axis=None, cmap='Greens')

# Display the styled correlation matrix
styled_matrix
# Out:
# <style type="text/css">
# #T_54b5e_row0_col0, #T_54b5e_row1_col1, #T_54b5e_row2_col2, #T_54b5e_row3_col3, #T_54b5e_row4_col4, #T_54b5e_row5_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_54b5e_row0_col1, #T_54b5e_row1_col0 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_54b5e_row0_col2, #T_54b5e_row2_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_54b5e_row0_col3, #T_54b5e_row3_col0 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_54b5e_row0_col4, #T_54b5e_row4_col0 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_54b5e_row0_col5, #T_54b5e_row5_col0 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_54b5e_row1_col2, #T_54b5e_row2_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_54b5e_row1_col3, #T_54b5e_row3_col1 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_54b5e_row1_col4, #T_54b5e_row4_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# ...

# %%
# Select only numerical columns
numerical_data = data.select_dtypes(include=['float64', 'int64'])

# Calculate the Spearman correlation matrix
correlation_matrix = numerical_data.corr(method='spearman').round(2)

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Create a figure with a size of 8x8
plt.figure(figsize=(8, 8))

# Create a heatmap with color gradient
sns.heatmap(correlation_matrix, 
            annot=True,                 # Annotate with correlation values
            cmap='Greens',              # Use green colormap
            mask=mask,                  # Mask the upper triangle
            vmin=-1, vmax=1,            # Set color range
            center=0,                   # Center the colormap at 0
            linewidths=0.5,            # Linewidths between cells
            linecolor='black',         # Line color between cells
            cbar_kws={'label': 'Correlation Value'})  # Colorbar label

# Add labels and title
plt.title('Spearman Correlation Matrix')  # Plot title

# Display the plot
plt.tight_layout()  # Adjust layout to fit labels
plt.show()
# Out:
# D:\instana\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# #### 3.3.2 Heatmaps

# %%
# Select only numerical columns
numerical_data = data.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numerical_data.corr().round(2)

# Create a figure with a size of 8x8
plt.figure(figsize=(8, 8))

# Create a heatmap
sns.heatmap(correlation_matrix, 
            annot=True,              # Annotate with correlation values
            cmap='Greens',           # Use green colormap
            center=0,                # Center the colormap at 0
            vmin=-1, vmax=1,         # Set color scale range
            linewidths=0.5,         # Line width between cells
            linecolor='black')      # Line color between cells

# Add labels and title
plt.title('Heatmap of Correlation Matrix')  # Plot title

# Display the plot
plt.tight_layout()  # Adjust layout to fit labels
plt.show()

# %%
# Select only numerical columns
numerical_data= data.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numerical_data.corr().round(2)

# Create a figure with a size of 8x8
plt.figure(figsize=(8, 8))

# Create a custom colormap
cmap = sns.diverging_palette(220, 20, as_cmap=True)

# Create a heatmap with custom colormap
sns.heatmap(correlation_matrix, 
            annot=True,              # Annotate with correlation values
            cmap=cmap,               # Use custom colormap
            center=0,                # Center the colormap at 0
            vmin=-1, vmax=1,         # Set color scale range
            linewidths=0.5,         # Line width between cells
            linecolor='black')      # Line color between cells

# Add labels and title
plt.title('Customized Heatmap of Correlation Matrix')  # Plot title

# Display the plot
plt.tight_layout()  # Adjust layout to fit labels
plt.show()

# %% [markdown]
# # 4. Weather patterns and trends

# %% [markdown]
# ### 4.1 Trends and patterns observed in the data

# %% [markdown]
# The coldest months are January and February, when average highs are approximately -7.37°C and -4.23°C. The hottest month is July, when the average high is almost 22.79°C. March marks the start of the temperature climb, which peaks in July and then starts to decline in September.Winter (December to February): The average temperature is roughly -4.98°C. Summer: The average temperature is 21.75 degrees Celsius from June to August. The average temperature during the spring (March through May) and fall (September through November) seasons is between 8.81°C and 9.47°C.
#
# With normal moistness of 81.30% and 75.73%, respectively, December and October have the highest stickiness levels.The lowest average humidity is recorded in April, when it is 56.15 percent.
#
# Mugginess is highest in the winter, averaging 72.97%. The least moist season is spring, with an average of 60.98%. Summertime and fall have quite high average humidity levels, at 63.57% and 72.33%, respectively. These impressions show a clear sporadic pattern in which temperatures peak in the middle of the year and decrease in the winter, whereas the winter months generally have higher relative humidity.

# %% [markdown]
# ### 4.2 Any anomalies or unusual patterns in the data

# %% [markdown]
# Extremely low temperatures of -17.3 °C were recorded on January 3, 2012. Extremely high temperatures—up to 30.4°C—predominated on August 26, 2012 hence an anomalies in the temparature
#
# August's high temperatures can be attributed to heatwaves, which often occur in the late spring and result in very high temperatures. Elevated Stickiness Levels: The extremely high moisture levels may be caused by meteorological factors such as haze, showers, or periods of heavy precipitation that cause immersion in the atmosphere. These anomalies are consistent with average weather conditions, but their edge may require additional research regarding specific climate events or local conditions during certain times.

# %% [markdown]
# # 5. Insights and conclusion

# %% [markdown]
# ### 5.1 Summary of key insights gained from the data

# %% [markdown]
# Variations in Temperature Throughout the Season: December through February are the coldest months, with average lows of -5°C, while June through August are the hottest, with average highs of 22°C. The temperature designs exhibit a consistent warming from winter to summer and cooling from summer to winter, indicating a reasonable sporadic cycle.
#
# Temperatures were abnormally low in the beginning of January, reaching as low as -17.3 °C, and exceptionally hot at the end of August, reaching 30.4 °C. Several times, abnormally high humidity levels, nearly 100%, were recorded, most likely in relation to fog or precipitation.
#
# There is a chance for critical sporadic shifts due to the sharp variations in temperature limits at the same period, which could be influenced by local meteorological events. The consistently high moisture measurements in the pre-winter and winter months suggest a preference for cloudy or windy conditions during these times, which may affect permeability and travel.

# %% [markdown]
# ### 5.2 How the insights are useful for weather predictions or other practical applications

# %% [markdown]
# Anticipating extreme weather events can facilitate the planning of coordinated logistics and supply chains, ensuring that deliveries are completed prior to the deterioration of conditions or altering routes to avoid affected areas.
#
#  Experts can use these tidbits of information to plan for extreme weather events. For instance, anticipating summer heat waves and ensuring sufficient heating supplies for winter can reduce risks for the most vulnerable.
#
# Models that predict similar anomalies can be made by identifying extremes in temperature and humidity. It is possible to issue early warnings for heat waves or cold snaps, minimizing the impact on infrastructure, agriculture, and health.
#
# High humidity, especially in the fall and winter, can cause buildings and roads to wear out more quickly. Convenient support timetables can be changed in light of these experiences to drag out the existence of framework.
#
# The high dampness levels in winter and pre-winter, related with hazy circumstances, can influence perceivability on streets and air terminals. Increasing the frequency of weather-related alerts or adjusting speed limits can both increase safety by knowing when these conditions are likely to occur.
#
# Ranchers can create planting and gathering strategies by using the experiences with temperature and mugginess examples. For example, choosing crops that can withstand summer heat can be guided by the fact that spring is usually drier, and irrigation needs can be identified with the help of this knowledge.

# %% [markdown]
# # 6. Recommendations for further analysis

# %% [markdown]
# ##### Financial Information
#
# Because weather affects economic activity, particularly in industries like retail, tourism, and agriculture, it is possible to investigate how weather affects economic indicators (such as productivity and retail sales) and weather conditions.
#
# ##### Topographic data
#
# Topographical variables such as elevation and slope can influence local weather patternspe. The addition of this information may aid in the explanation of regional differences in wind, precipitation, and temperatTopographical variables such as elevation and slope can influence local weather patterns
#
# ##### Air Quality
#
# Information on air quality, such as pollutant or particulate matter levels, could be useful in evaluating how weather patterns impact pollution and public health.
#
# ##### Seasonal Shifts
#
# Determining if seasonal intensity or timing changes over time can help us understand how climate change is affecting local weather patterns.
#
# e.
